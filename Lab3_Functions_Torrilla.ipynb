# %%
LAST_NAME = "Torrilla"
STUDENT_ID = "TUPM-25-0921"

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:", SEED_DIGIT)
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: Torrilla
# Seed Digit: 1
# Digit Sum: 19
# Surname Length: 8

# %%
def greet():
    print("=" * 40)
    print(f"System Initialized for: {LAST_NAME}")
    print("=" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code

greet()
print("Identity Code:", identity_code())
# Out:
# ========================================
# System Initialized for: Torrilla
# ========================================
# Identity Code: 8

# %%
global_value = ID_SUM

def scope_test():
    global_value = SEED_DIGIT
    print("Inside Function:", global_value)

scope_test()
print("Outside Function:", global_value)
# Out:
# Inside Function: 1
# Outside Function: 19

# %%
def user_summary(title, *scores, **info):
    print(f"=== {title} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average:", round(average,2))

    for k,v in info.items():
        print(f"{k}: {v}")

    return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id = STUDENT_ID,
    surname = LAST_NAME
)
# Out:
# === Torrilla Academic Report ===
# Scores: (10, 19, 40)
# Total: 69
# Average: 23.0
# id: TUPM-25-0921
# surname: Torrilla

# %%
def compute_area(radius):
    return 3.1416 * radius ** 2

area = compute_area(SEED_DIGIT + 2)
print("Computed Area:", round (area, 2))
# Out:
# Computed Area: 28.27

# %%
print (F"My × (ID_SUM) is: {ID_SUM}.")
print(f"My y (SEED DIGIT) is: {SEED_DIGIT}")


result = safe_calculator(ID_SUM, SEED_DIGIT)
print(f"Safe Calculation: {result}")
# Out:
# My × (ID_SUM) is: 19.
# My y (SEED DIGIT) is: 1
# Safe Calculation: {'x': 19, 'y': 1, 'result': 19.0}

# %%
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n-1)

print("Factorial of Seed Digit:", factorial(SEED_DIGIT))
# Out:
# Factorial of Seed Digit: 1

# %%
def reverse(text):
    if len(text) <= 1:
        return text
    return text[-1] + reverse(text[:-1])

print("Reversed Surname:", reverse(LAST_NAME))
# Out:
# Reversed Surname: allirroT

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print("Executing:", func.__name__)
        return func(*args, **kwargs)
    return wrapper

@logger
def multiply (x, y):
    return x * y
print("Multiplication:", multiply(SEED_DIGIT, NAME_LENGTH))
# Out:
# Executing: multiply
# Multiplication: 8

# %%
data = list(range(1, SEED_DIGIT + 10))
squared = list(map(lambda x: x**2, data))
print ("Squared Data:", squared)
# Out:
# Squared Data: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
#grades.py

def even_squares(limit):
    for i in range(limit):
        if i % 2 == 0:
            yield i**2 

for value in even_squares(NAME_LENGTH + SEED_DIGIT) :
    print(value)
# Out:
# 0
# 4
# 16
# 36
# 64
